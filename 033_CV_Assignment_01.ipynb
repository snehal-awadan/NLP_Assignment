# %% [markdown]
# # Assignment No : 01
#
# Name: Snehal Awadan
#
# PRN: 240340128033
#
# Module: CV

# %% [markdown]
# Location: images folder on https://mitu.co.in/dataset

# %% [markdown]
# # Q1)

# %% [markdown]
# # 1) Load the image:

# %%
import cv2
img_cv = cv2.imread('sachin.jpg')

# %% [markdown]
# # 2) Size and shape of the image

# %%
print('The shape of the given image is: ',img_cv.shape)
# Out:
# The shape of the given image is:  (1075, 850, 3)

# %%
print('The size of the given image is: ',img_cv.size)
# Out:
# The size of the given image is:  2741250

# %% [markdown]
# # 3) The color space model

# %%
# Convert the image to different color spaces
image_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
image_hsv = cv2.cvtColor(img_cv, cv2.COLOR_BGR2HSV)
image_gray = cv2.cvtColor(img_cv, cv2.COLOR_BGR2GRAY)

# Display the images in different color spaces
cv2.imshow('Image in RGB', image_rgb)
cv2.imshow('Image in HSV', image_hsv)
cv2.imshow('Image in Grayscale', image_gray)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# BGR pixel value at (0, 0): [26 19 16]
# RGB pixel value at (0, 0): [16 19 26]
# HSV pixel value at (0, 0): [111  98  26]
# LAB pixel value at (0, 0): [ 15 130 123]
# Grayscale pixel value at (0, 0): 19

# %% [markdown]
# # 4) Display using cv and matplotlib

# %%
# using cv:

cv2.imshow('Sachine Image', img_cv)
cv2.waitKey(0)   # press any key to close.
cv2.destroyAllWindows()

# %%
# Using matplotlib :

import matplotlib.pyplot as plt

img_plt = plt.imread('sachin.jpg')
plt.imshow(img_plt)

# %% [markdown]
# # Q2) Show the image in the matrix of 5 x 5 with different cmap:

# %%
img = cv2.imread('sachin.jpg',0)

plt.figure(figsize=(16,8))

plt.subplot(2,4,1)
plt.title('Coolwarm')
plt.imshow(img, cmap = 'coolwarm')

plt.subplot(2,4,2)
plt.title('rainbow')
plt.imshow(img, cmap = 'rainbow')

plt.subplot(2,4,3)
plt.title('tab10')
plt.imshow(img, cmap = 'tab10')

plt.subplot(2,4,4)
plt.title('seismic')
plt.imshow(img, cmap = 'seismic')

plt.subplot(2,4,5)
plt.title('twilight')
plt.imshow(img, cmap = 'twilight')

plt.subplot(2,4,6)
plt.title('turbo')
plt.imshow(img, cmap = 'turbo')

plt.subplot(2,4,7)
plt.title('BuGn')
plt.imshow(img, cmap = 'BuGn')

# %% [markdown]
# # 3. Change the pixels from (100,150) to (200,350) to while color.

# %%
start = (100,150)
end = (200,350)

img_cv[start[1]:end[1], start[0]:end[0]] = [255,255,255]

# Display the modified image
cv2.imshow('Original image',img_cv )
cv2.imshow('New Image', img_cv)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Q2)

# %% [markdown]
# # 1. Find height, width, total frames and fps of the video

# %%
# load the video:
vid = cv2.VideoCapture('nature.mp4')

# %%
width = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
frames = int(vid.get(cv2.CAP_PROP_FRAME_COUNT))
fps = int(vid.get(cv2.CAP_PROP_FPS))    # frame per second

# %%
print('The height is: ', height)
print('The width is: ', width)
print('total frames: ', frames)
print('FPS:', fps)
# Out:
# The height is:  720
# The width is:  1270
# total frames:  1409
# FPS: 26

# %% [markdown]
# # 2. Play the video in frames

# %%
# read the video again:
vid = cv2.VideoCapture('nature.mp4')

while True:
    ret, frame = vid.read()
    if not ret:    # ret = false
        break
    # process the frame (e.g. apply filters, detect objects)
    cv2.imshow('Video', frame) # dislay the frame that read earlier

    # if you want to stop video in between: ==> press 'q'
    if cv2.waitKey(3) == ord('q'):   # ord => ascii valu
        break
cv2.destroyAllWindows()

# %% [markdown]
# # 3. Save the image at 50th second.

# %%
#get frame at a specific timestamp

timestamp='00:00:50.00'
hours,minutes,seconds=[float(i) for i in timestamp.split(':')]

#get number of frames up to timestamp
trigger_frame=hours *3600*fps+ minutes *60*fps +seconds*fps

#Go to frame selected by timestamp
vid.set(1,trigger_frame)
success,frame=vid.read()

#save the frame into an image file
if success:
    cv2.imwrite("nature_time_50sec.jpg",frame)
